# %% [markdown]
# # Day 5: Linear Regression & Evaluation

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y, color='blue') # Real data
plt.plot(X, model.predict(X), color='red') # AI's best-fit line
plt.title("Hours vs Score: AI Prediction Line")
plt.show()

# %% [markdown]
# #### What happens to the prediction if we only give the model 2 rows of data to train on instead of 8?

# %% [markdown]
# #### If the model is trained on only 2 data points instead of 8, it will not learn the true pattern. The predictions will be inaccurate and unreliable because the model does not have enough data to generalize properly.
